# %%
import string # library used to deal with some text data
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # data visualization library
import matplotlib.pyplot as plt # plotting library

# %%
df = pd.read_csv("/Users/User/Desktop/ML0000/python/8/winequality-red.csv")
display(df.head(10))
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
fig, ax = plt.subplots(figsize=(10,10))         # Samplefigsize in inches
sns.heatmap(df.corr(), annot=True, linewidths=.5, ax=ax)

# %%
pd.plotting.scatter_matrix(df[["quality","alcohol","sulphates","citric acid","fixed acidity","residual sugar"]],
                           alpha=0.1,figsize=(10,10))
plt.title('Scatter Matrix plot of our adjusted Dataframe')
# Out:
# Text(0.5, 1.0, 'Scatter Matrix plot of our adjusted Dataframe')

# %%
plt.figure(figsize=(10,10))
pd.plotting.radviz(df[["quality","alcohol","sulphates","citric acid","fixed acidity","residual sugar"]],'quality')

# %%
df["quality"] = pd.cut(df["quality"],bins=[0,6.5,10],labels=["Good","Bad"])
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality
# 0      9.4    Good
# 1      9.8    Good
# 2      9.8    Good
# ...

# %%
import plotly.express as px
fig = px.pie(df, names="quality",  title='Distribution of Wine Quality')
fig.show()
# Out:
# <div>                            <div id="19ff2c39-a2e6-4029-a615-ee619702cfc7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19ff2c39-a2e6-4029-a615-ee619702cfc7")) {                    Plotly.newPlot(                        "19ff2c39-a2e6-4029-a615-ee619702cfc7",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "quality=%{label}<extra></extra>", "labels": ["Good", "Good", "Good", "Good", "Good", "Good", "Good", "Bad", "Bad", "Good", "Good", "Good", "Good", "Good", "Good", "Good", "Bad", "Good", "Good", "Good", "Good", "Good", "Good", "Good", "Good", "Good", "Good", "Good", "Good", "Good", "Good", "Good", "Good", "Good", "Good", "Good", "Good", "Bad", "Good", "Good", "Good", "Good", "Good", "Good", "Good", "
# ...

# %%
from sklearn.cluster import KMeans
from sklearn import preprocessing,svm,neighbors
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier,BaggingClassifier,GradientBoostingClassifier,RandomForestClassifier,VotingClassifier,StackingClassifier
from sklearn.ensemble import ExtraTreesClassifier

df=df[["quality","alcohol","sulphates","citric acid","fixed acidity","residual sugar"]]
X=df.drop(["quality"],1)
y=df["quality"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2,random_state=1)
#lnr=LinearRegression()
lr=LogisticRegression()
knn=neighbors.KNeighborsClassifier(n_neighbors = 5) 
svm0=svm.SVC(random_state = 1)
nb=GaussianNB()
dtc = DecisionTreeClassifier()
rf = RandomForestClassifier(n_estimators = 3000, random_state = 1)
ada=AdaBoostClassifier()
bagging=BaggingClassifier(n_estimators=300)
ex_tree=ExtraTreesClassifier(n_estimators=300)
xgb=XGBClassifier()

#lnr.fit(X_train,y_train)
lr.fit(X_train,y_train)
knn.fit(X_train,y_train)
svm0.fit(X_train,y_train)
nb.fit(X_train,y_train)
dtc.fit(X_train,y_train)
rf.fit(X_train,y_train)
ada.fit(X_train,y_train)
bagging.fit(X_train,y_train)
ex_tree.fit(X_train,y_train)
xgb.fit(X_train,y_train)

accuracy={}
#accuracy["LinearRegression"]=lnr.score(X_test,y_test)*100
accuracy["Logisticregression"]=lr.score(X_test,y_test)*100
accuracy["Knn"]=knn.score(X_test,y_test)*100
accuracy["SVM"]=svm0.score(X_test,y_test)*100
accuracy["Naive Bayes"]=nb.score(X_test,y_test)*100
accuracy["Random Forest"]=rf.score(X_test,y_test)*100
accuracy["AdaBoost"]=ada.score(X_test,y_test)*100
accuracy["Bagging"]=bagging.score(X_test,y_test)*100
accuracy["Extra Trees"]=ex_tree.score(X_test,y_test)*100
accuracy["XGB"]=xgb.score(X_test,y_test)*100

print(accuracy)
# Out:
# {'Logisticregression': 89.375, 'Knn': 89.0625, 'SVM': 90.0, 'Naive Bayes': 87.1875, 'Random Forest': 93.125, 'AdaBoost': 87.1875, 'Bagging': 91.5625, 'Extra Trees': 92.8125, 'XGB': 90.3125}

# %%
p=sns.barplot(list(accuracy.keys()),list(accuracy.values()),palette="bright")
_=plt.setp(p.get_xticklabels(),rotation=90)
plt.show()
